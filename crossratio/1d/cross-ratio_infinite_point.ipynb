# %%
from kingdon import Algebra
import math
import time

#alg = Algebra(1, 0, 1)
alg = Algebra(2, 0, 1) # we use 2d pga for visualization
locals().update(alg.blades)

# %%
# Construct points
point = lambda x: (e0 + x * e1).dual()
# here we use the dual to projet on e2, inner products will give scalars
crossRatio = lambda a,b,c,d: ( (a & c) * ( b & d) ) / ( (b & c) * ( a & d) ) 
dist = lambda x,y: x & y

# %%
A = point(-1)
B = point(1)
C = point(2)
D = lambda: A - B # direction of the line same as (B-A) for the cr formula

# %%
AB = lambda: A & B

# %%
k = lambda: f"cross-ration : {crossRatio(A,B,C,D):.3f}"

# %%
alg.graph(
    "Drag the points A,B,C,D",                         # render titles
    0x00AA88, AB,                                      # render line
    0x224488, A, "A", B, "B", C, "C",                  # render points 
    0x884422, e12+e01+e02,k,                           # render cross-ratio
    0x882244, D, "D",                                  # render vectors
    lineWidth=3, grid=True, labels=True, animate=True,
)
# Out:
# GraphWidget(cayley=[['1', 'e0', 'e1', 'e2', 'e01', 'e02', 'e12', 'e012'], ['e0', '0', 'e01', 'e02', '0', '0', …
